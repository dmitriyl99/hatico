# %%
import pandas as pd

# %%
df = pd.read_json('datasets/moscow_cams.json', encoding='windows-1251')

# %%
df
# Out:
#                                                   Address   global_id  \
# 0                город Москва, Солдатский переулок, дом 8   904476341
# 1          город Москва, Луговой проезд, дом 10, корпус 1   904476342
# 2              город Москва, Зеленодольская улица, дом 24   904476345
# 3       город Москва, Самаркандский бульвар, дом 24, к...   904476346
# 4       город Москва, Новомарьинская улица, дом 16, ко...   904476348
# ...                                                   ...         ...
# 103328  Российская Федерация, город Москва, внутригоро...  1150202870
# 103329  Российская Федерация, город Москва, внутригоро...  1150202871
# 103330  Российская Федерация, город Москва, внутригоро...  1150202872
# 103331  Российская Федерация, город Москва, внутригоро...  1150202873
# 103332     город Москва, Донецкая улица, дом 30, корпус 2  1150202874
#
#                                      AdmArea               District  \
# ...

# %%
df_sample = df.sample(16000)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16000 entries, 87067 to 14155
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Address         16000 non-null  object
#  1   global_id       16000 non-null  int64
#  2   AdmArea         16000 non-null  object
#  3   District        16000 non-null  object
#  4   ID              16000 non-null  object
#  5   OVDAddress      16000 non-null  object
#  6   OVDPhone        16000 non-null  object
#  7   UNOM            16000 non-null  int64
#  8   Photo           16000 non-null  object
#  9   geoData         16000 non-null  object
#  10  geodata_center  16000 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.5+ MB

# %%
df_sample[['ID', 'Address', 'District', 'geoData']].to_csv('datasets/moscow_cameras.csv')

# %%
pd.read_csv('datasets/moscow_cameras.csv')
# Out:
#        Unnamed: 0                   ID  \
# 0           87067    PVN_hd_VAO_2181_1
# 1           49698   PVN_hd_UVAO_9665_2
# 2           11217   PVN_hd_SVAO_3473_3
# 3           47899    PVN_hd_ZAO_9848_3
# 4           27483  PVN_hd_VAO_2_5033_4
# ...           ...                  ...
# 15995       48171    PVN_hd_UAO_7262_1
# 15996       89034    PVN_hd_VAO_2414_4
# 15997       86420    PVN_hd_VAO_1617_2
# 15998       18684   PVN_hd_UZAO_8943_1
# 15999       14155   PVN_hd_SVAO_4100_1
#
#                                                  Address  \
# 0      город Москва, 15-я Парковая улица, дом 46, кор...
# 1      город Москва, улица Верхние Поля, дом 42, корп...
# 2      Российская Федерация, город Москва, внутригоро...
# 3             город Москва, Кутузовский проспект, дом 82
# 4          город Москва, Бойцовая улица, дом 6, корпус 6
# ...                                                  ...
# 15995  Российская Федерация, город Москва, внутригоро...
# ...
